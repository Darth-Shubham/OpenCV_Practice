# %%
import cv2
import numpy as np

# %%
img = cv2.imread('bnw.jpg')
img = cv2.resize(img, None, fx=.5, fy=.5)

# %%
kernel = np.ones((5,5), np.uint8)

# %% [markdown]
# # Erosion

# %% [raw]
# Erosion is used to determine wheather a pixel will be white or black
# This is done by Kernel. If all the values in a kernel are 255(white) the center remaines white but if even one pixel is 0(Black) then the center is changes to black.

# %%
erosion = cv2.erode(img, kernel, iterations = 1)

# %% [markdown]
# # Dilation

# %% [raw]
# Dilation is used to determine wheather a pixel will be white or black
# This is done by Kernel. If all the values in a kernel are 0(Black) the center remaines Black but if even one pixel is 255(White) then the center is changes to White.

# %%
dilation = cv2.dilate(img, kernel, iterations = 1)

# %% [markdown]
# # Opening

# %% [raw]
# Erosion Followed by Dilation
# Used to remove noise from background(Black Portion) of the Mask

# %%
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

# %% [markdown]
# # Closing

# %% [raw]
# Dilation followed by Erosion
# Used to remove noise from foreground(White Portion) of the Mask

# %%
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

# %% [markdown]
# # Gradient

# %% [raw]
# Dilated Image - Eroded Image
# Used to create a outline of the object

# %%
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)

# %% [markdown]
# # TopHat

# %% [raw]
# Difference between Input image and Opening image
# Used to highlight minor details in image

# %%
topHat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)

# %% [markdown]
# # BlackHat

# %% [raw]
# Closing image - Input Image
# To find bright object on Dark Background

# %%
blackHet = cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernel)

# %%
cv2.imshow('Original', img)
cv2.imshow('Erosion', erosion)
cv2.imshow('Dilation', dilation)
cv2.imshow('Opening', opening)
cv2.imshow('Closing', closing)
cv2.imshow('Gradient', gradient)
cv2.imshow('TopHat', topHat)
cv2.imshow('BlackHet', blackHet)


if cv2.waitKey(0) & 0xFF == ord('q'):
    cv2.destroyAllWindows()
