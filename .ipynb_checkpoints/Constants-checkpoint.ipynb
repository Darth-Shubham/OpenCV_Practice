# %%
COLOURS = {'blue': (255,0,0), 'green': (0,255,0), 'red': (0,0,255), 'yellow': (0,255,255), 'cyan': (255,255,0),'margenta': (255,0,255),'black': (0,0,0), 'white': (255,255,255),'gray': (125,125,125),'dark_grey': (50,50,50), 'light_gray': (220,220,220), 'amber': (0,191,255)}

# %%
RADIUS = 220
CANVAS = (500,500,3)
CENTER = (250,250)
