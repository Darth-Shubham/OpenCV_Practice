# %%
import cv2
image = cv2.imread('gray_scale1.jpg')
gaussian_pyramid = [image]
laplacian_pyramid = []

# Create Gaussian pyramid
for i in range(4):
    image = cv2.pyrDown(image)
    gaussian_pyramid.append(image)

# Create Laplacian pyramid by subtracting successive Gaussian levels
for i in range(3, 0, -1):
    gauss_expanded = pycv2.rUp(gaussian_pyramid[i])
    gauss_expanded_resized = cv2.resize(gauss_expanded, (gaussian_pyramid[i-1].shape[1], gaussian_pyramid[i-1].shape[0]))
    laplacian = cv2.subtract(gaussian_pyramid[i-1], gauss_expanded_resized)
    laplacian_pyramid.append(laplacian)

# %%
for img in laplacian_pyramid:
    cv2.imshow('image', img)
    cv2.waitKey(0)

# %%
img = cv2.cvtColor(laplacian_pyramid[2], cv2.COLOR_BGR2GRAY)
cv2.imshow('image', img)
cv2.waitKey(0)
# Out:
# -1

# %%
img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 2)
cv2.imshow('image', img)
cv2.waitKey(0)
# Out:
# -1

# %%
cont, _ = cv2.findContours(img, mode = cv2.RETR_EXTERNAL, method = cv2.CHAIN_APPROX_SIMPLE)
new_img = cv2.drawContours(gaussian_pyramid[0], cont, -1, (0,0,0), 2)

# %%
cv2.imshow('image', new_img)
cv2.waitKey(0)
# Out:
# -1
