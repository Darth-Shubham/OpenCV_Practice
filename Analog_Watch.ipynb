# %%
import cv2
import numpy as np
# %run Constants.ipynb
# %run Helper_functions.ipynb

# %%
image = np.zeros(CANVAS, dtype = np.int32)
image[:] = [255,255,255]

# %%
hours_init, hours_dest = get_ticks()

# %%
for i in range(len(hours_init)):
    if i%5 == 0:
        cv2.line(image, hours_init[i], hours_dest[i], COLOURS['black'], 3)
    else:
        cv2.circle(image, hours_init[i], 5, COLOURS['dark_grey'], -1)

cv2.circle(image, (CENTER[0], CENTER[1]), RADIUS, COLOURS['yellow'], 2)
cv2.putText(image, "ANALOG", (130, 170), cv2.FONT_HERSHEY_TRIPLEX, 2, COLOURS['amber'], 1, cv2.LINE_AA)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
while True:
    image_original = image.copy()
    clock_face = draw_time(image_original)
    clock_face = clock_face.astype('uint8')

    cv2.imshow('Clock', clock_face)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close any OpenCV windows
cv2.destroyAllWindows()
